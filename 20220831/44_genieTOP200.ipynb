# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt
import time

# %%
targetSite = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=1'
req = requests.get(targetSite)
print(req)
html = req.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <Response [200]>
# <br/>
# <br/>
# <center>
# <img src="http://www.geniemusic.co.kr/images/common/logo_r1.png"/><br/>
# <h2> <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/> ì ììì²­ì´ ë³´ìì ì±ì ìí´ ì°¨ë¨ëììµëë¤. ë¹ì¬ ê³ ê°ì¼í°ë¡ ë¬¸ìí´ì£¼ì­ìì¤.<br/><br/>
# The security policy of the connection request is blocked. Contact your customer service representative.<br/><br/>
# ì§ëë®¤ì§ ê³ ê°ì¼í° 1577-5337<br/><br/>
# </h2>
# </center>
# <br/>

# %%
targetSite = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=1'
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
req = requests.get(targetSite, headers=header)
print(req)
html = req.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <Response [200]>
#
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--[if lte IE 6]><html dir="ltr" class="no-js ie6"><![endif]-->
# <!--[if lte IE 7]><html dir="ltr" class="no-js ie7"><![endif]-->
# <!--[if IE 8]><html dir="ltr" class="no-js ie8"><![endif]-->
# <!--[if IE 9]><html dir="ltr" class="no-js ie9"><![endif]-->
# <!--[if (gte IE 10)|!(IE)]><!--><html class="no-js" dir="ltr"><!--<![endif]-->
# <title>음악, 그리고 설레임 - 지니</title>
# <meta charset="utf-8"/>
# <meta content="d17289f97c7f294985a9b0eb3649a45ac5ceeee2" name="naver-site-verification"/>
# <meta content="-l7MNwwsDcn29Pnu00OagSrpDUPbjqLYoY08rhXLde8" name="google-site-verification"/>
# <meta content="가격은 가볍게, 추천은 확실하게! 최저가로 즐기는 프리미어 사운드! 국내 최초 실시간 TOP 200 차트" name="description"/>
# <meta content="width=1200" name="viewport"/>
# <meta content="" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=1 =>   1 ~  50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=2 =>  51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg='
for i in range(1, 5):
    # targetSite = url + str(i)
    targetSite = '{}{}'.format(url, i)
    print(targetSite)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    req = requests.get(targetSite, headers=header)
    # print(req)
    html = req.text
    # print(html)
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup)
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    for i in range(len(titles)):
        # print('{:3d}위 {}'.format(i + 1, titles[i].text.strip()))
        # print('{:3d}위 {}'.format(i + 1, titles[i].text.split('\n')[-1].strip()))
        print('{:3d}위 {}'.format(i + 1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 After LIKE
#   2위 Pink Venom
#   3위 Attention
#   4위 Hype boy
#   5위 FOREVER 1
#   6위 LOVE DIVE
#   7위 그때 그 순간 그대로 (그그그)
#   8위 보고싶었어
#   9위 Cookie
#  10위 SNEAKERS
#  11위 TOMBOY
#  12위 도깨비불 (Illusion)
#  13위 That That (Prod. & Feat. SUGA of BTS)
#  14위 그라데이션
#  15위 사랑인가 봐
#  16위 사랑은 늘 도망가
#  17위 나의 X에게
#  18위 POP!
#  19위 정이라고 하자 (Feat. 10CM)
#  20위 우리들의 블루스
#  21위 Love story
#  22위 ELEVEN
#  23위 That's Hilarious
#  24위 내가 아니라도
#  25위 다정히 내 이름을 부르면
#  26위 내 기쁨은 너가 벤틀리를 끄는 거야
#  27위 다시 만날 수 있을까
#  28위 LOVE me
#  29위 해요 (2022)
#  30위 FEARLESS
#  31위 이제 나만 믿어요
#  32위 신호등
#  33위 봄여름가을겨울 (Still Life)
#  34위 잠수이별 (Prod. by 코드 쿤스트)
#  35위 Girls
#  36위 취중고백
#  37위 무지개
#  38위 Stay
#  39위 아버지
#  40위 Talk that Talk
#  41위 MY BAG
#  42위 A bientot
#  43위 팡파레
#  44위 통화연결음
#  45위 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)
#  46위 열이올라요 (Heart Burn)
#  47위 사랑해 진짜
#  48위 손이 참 곱던 그대
#  49위 새벽에 걸려온 너의 전화는
#  50위 너의 모든 순간

# %%
# 아티스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    req = requests.get(targetSite, headers=header)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    # print(artists)
    # print(len(artists))
    
    # i = 1
    # for artist in artists[5:]:
        # print('{:3d}위 {}'.format(i, artist.text.strip()))
        # i += 1
        
    # for i in range(len(artists[5:])):
        # print('{:3d}위 {}'.format(i + 1, artists[i].text.strip()))
    
    for i in range(5, len(artists)):
        # print('{:3d}위 {}'.format(i - 4, artists[i].text.strip()))
        # print('{:3d}위 {}'.format(i - 4, artists[i].text.split('\n')[0]))
        print('{:3d}위 {}'.format(i - 4, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 IVE (아이브)
#   2위 BLACKPINK
#   3위 NewJeans
#   4위 NewJeans
#   5위 소녀시대 (GIRLS' GENERATION)
#   6위 IVE (아이브)
#   7위 WSG워너비 (가야G)
#   8위 WSG워너비 (4FIRE)
#   9위 NewJeans
#  10위 ITZY (있지)
#  11위 (여자)아이들
#  12위 aespa
#  13위 싸이 (Psy)
#  14위 10CM
#  15위 멜로망스 (MeloMance)
#  16위 임영웅
#  17위 경서
#  18위 나연 (TWICE)
#  19위 BIG Naughty (서동현)
#  20위 임영웅
#  21위 볼빨간사춘기
#  22위 IVE (아이브)
#  23위 Charlie Puth
#  24위 주호
#  25위 경서예지 & 전건호
#  26위 김승민
#  27위 임영웅
#  28위 BE'O (비오)
#  29위 #안녕
#  30위 LE SSERAFIM (르세라핌)
#  31위 임영웅
#  32위 이무진
#  33위 BIGBANG (빅뱅)
#  34위 우원재 (Woo) & meenoi (미노이)
#  35위 aespa
#  36위 김민석 (멜로망스)
#  37위 임영웅
#  38위 The Kid LAROI & Justin Bieber
#  39위 임영웅
#  40위 TWICE (트와이스)
#  41위 (여자)아이들
#  42위 임영웅
#  43위 다비치
#  44위 보라미유 & MJ (써니사이드)
#  45위 이석훈
#  46위 선미
#  47위 임영웅
#  48위 임영웅
#  49위 한동근
#  50위 성시경

# %%
# 크롤링한 4페이지의 결과를 리스트 하나에 모은다.
genie = []
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220830&hh=22&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    req = requests.get(targetSite, headers=header)
    time.sleep(0.5)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    
    for j in range(50):
        # (가수, 제목) 형태의 튜플로 만들어 genie 리스트에 저장한다.
        genie.append(
            (artists[j + 5].text.strip().split('\n')[0], titles[j].text.strip().split('\n')[0])
        )
# print(len(genie))
print(genie)
# Out:
# [('IVE (아이브)', 'After LIKE'), ('BLACKPINK', 'Pink Venom'), ('NewJeans', 'Attention'), ('NewJeans', 'Hype boy'), ("소녀시대 (GIRLS' GENERATION)", 'FOREVER 1'), ('IVE (아이브)', 'LOVE DIVE'), ('WSG워너비 (가야G)', '그때 그 순간 그대로 (그그그)'), ('WSG워너비 (4FIRE)', '보고싶었어'), ('NewJeans', 'Cookie'), ('ITZY (있지)', 'SNEAKERS'), ('(여자)아이들', 'TOMBOY'), ('aespa', '도깨비불 (Illusion)'), ('싸이 (Psy)', 'That That (Prod. & Feat. SUGA of BTS)'), ('10CM', '그라데이션'), ('멜로망스 (MeloMance)', '사랑인가 봐'), ('임영웅', '사랑은 늘 도망가'), ('경서', '나의 X에게'), ('나연 (TWICE)', 'POP!'), ('BIG Naughty (서동현)', '정이라고 하자 (Feat. 10CM)'), ('임영웅', '우리들의 블루스'), ('볼빨간사춘기', 'Love story'), ('IVE (아이브)', 'ELEVEN'), ('Charlie Puth', "That's Hilarious"), ('주호', '내가 아니라도'), ('경서예지 & 전건호', '다정히 내 이름을 부르면'), ('김승민', '내 기쁨은 너가 벤틀리를 끄는 거야'), ('임영웅', '다시 만날 수 있을까'), ("BE'O (비오)", 'LOVE me'), ('#안녕', '해요 (2022)'), ('LE SSERAFIM (르세라핌)', 'FEARLESS'), ('임영웅', '이제 나만 믿어요'), ('이무진', '신호등'), ('BIGBANG (빅뱅)', '봄여름가을겨울 (Still Life)'), ('우원재 (Woo) & meenoi (미노이)', '잠수이별 (Prod. by
# ...

# %%
print(dt.now())
for i in range(200):
    print('{:3d}위 {} - {}'.format(i + 1, genie[i][0], genie[i][1]))
# Out:
# 2022-08-31 20:21:07.729905
#   1위 IVE (아이브) - After LIKE
#   2위 BLACKPINK - Pink Venom
#   3위 NewJeans - Attention
#   4위 NewJeans - Hype boy
#   5위 소녀시대 (GIRLS' GENERATION) - FOREVER 1
#   6위 IVE (아이브) - LOVE DIVE
#   7위 WSG워너비 (가야G) - 그때 그 순간 그대로 (그그그)
#   8위 WSG워너비 (4FIRE) - 보고싶었어
#   9위 NewJeans - Cookie
#  10위 ITZY (있지) - SNEAKERS
#  11위 (여자)아이들 - TOMBOY
#  12위 aespa - 도깨비불 (Illusion)
#  13위 싸이 (Psy) - That That (Prod. & Feat. SUGA of BTS)
#  14위 10CM - 그라데이션
#  15위 멜로망스 (MeloMance) - 사랑인가 봐
#  16위 임영웅 - 사랑은 늘 도망가
#  17위 경서 - 나의 X에게
#  18위 나연 (TWICE) - POP!
#  19위 BIG Naughty (서동현) - 정이라고 하자 (Feat. 10CM)
#  20위 임영웅 - 우리들의 블루스
#  21위 볼빨간사춘기 - Love story
#  22위 IVE (아이브) - ELEVEN
#  23위 Charlie Puth - That's Hilarious
#  24위 주호 - 내가 아니라도
#  25위 경서예지 & 전건호 - 다정히 내 이름을 부르면
#  26위 김승민 - 내 기쁨은 너가 벤틀리를 끄는 거야
#  27위 임영웅 - 다시 만날 수 있을까
#  28위 BE'O (비오) - LOVE me
#  29위 #안녕 - 해요 (2022)
#  30위 LE SSERAFIM (르세라핌) - FEARLESS
#  31위 임영웅 - 이제 나만 믿어요
#  32위 이무진 - 신호등
# ...

# %%
file = open('./output/genieTOP200.txt', 'w')
file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
for i in range(200):
    file.write('{:3d}위 {} - {}\n'.format(i + 1, genie[i][0], genie[i][1]))
file.close()
print('파일로 저장완료')
# Out:
# 파일로 저장완료

# %%
with open('./output/genieTOP200.txt', 'w') as file:
    file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
    for i in range(200):
        file.write('{:3d}위 {} - {}\n'.format(i + 1, genie[i][0], genie[i][1]))
print('파일로 저장완료')
# Out:
# 파일로 저장완료

# %%
try:
    file = open('./output/genieTOP200.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line.rstrip())
except FileNotFoundError:
    print('디스크에 파일이 없습니다.')
# Out:
# 2022-08-31 20:24:38
#   1위 IVE (아이브) - After LIKE
#   2위 BLACKPINK - Pink Venom
#   3위 NewJeans - Attention
#   4위 NewJeans - Hype boy
#   5위 소녀시대 (GIRLS' GENERATION) - FOREVER 1
#   6위 IVE (아이브) - LOVE DIVE
#   7위 WSG워너비 (가야G) - 그때 그 순간 그대로 (그그그)
#   8위 WSG워너비 (4FIRE) - 보고싶었어
#   9위 NewJeans - Cookie
#  10위 ITZY (있지) - SNEAKERS
#  11위 (여자)아이들 - TOMBOY
#  12위 aespa - 도깨비불 (Illusion)
#  13위 싸이 (Psy) - That That (Prod. & Feat. SUGA of BTS)
#  14위 10CM - 그라데이션
#  15위 멜로망스 (MeloMance) - 사랑인가 봐
#  16위 임영웅 - 사랑은 늘 도망가
#  17위 경서 - 나의 X에게
#  18위 나연 (TWICE) - POP!
#  19위 BIG Naughty (서동현) - 정이라고 하자 (Feat. 10CM)
#  20위 임영웅 - 우리들의 블루스
#  21위 볼빨간사춘기 - Love story
#  22위 IVE (아이브) - ELEVEN
#  23위 Charlie Puth - That's Hilarious
#  24위 주호 - 내가 아니라도
#  25위 경서예지 & 전건호 - 다정히 내 이름을 부르면
#  26위 김승민 - 내 기쁨은 너가 벤틀리를 끄는 거야
#  27위 임영웅 - 다시 만날 수 있을까
#  28위 BE'O (비오) - LOVE me
#  29위 #안녕 - 해요 (2022)
#  30위 LE SSERAFIM (르세라핌) - FEARLESS
#  31위 임영웅 - 이제 나만 믿어요
#  32위 이무진 - 신호등
# ...
