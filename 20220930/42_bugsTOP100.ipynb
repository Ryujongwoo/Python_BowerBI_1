# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2022-08-30 22:06:52.502911

# %%
targetSite = 'https://music.bugs.co.kr/chart'
req = requests.get(targetSite)
# print(req)
html = req.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 클로링
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
# print(len(titles))

for i in range(len(titles)):
    # print('{:3d}위 {}'.format(i + 1, titles[i].text.strip()))
    # print('{:3d}위 {}'.format(i + 1, titles[i].text.split('\n')[1]))
    print('{:3d}위 {}'.format(i + 1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 After LIKE
#   2위 Pink Venom
#   3위 Hype Boy
#   4위 Attention
#   5위 가솔린 (Gasoline)
#   6위 한 밤의 꿈처럼
#   7위 FOREVER 1
#   8위 Talk that Talk
#   9위 Can’t Stop Shining
#  10위 Cookie
#  11위 Better (Feat. BIG Naughty)
#  12위 Bad News
#  13위 LOVE DIVE
#  14위 Young & Wild
#  15위 START UP
#  16위 하루만
#  17위 SNEAKERS
#  18위 Villain (Feat. 제노 of NCT)
#  19위 도깨비불 (Illusion)
#  20위 ELEVEN
#  21위 FEARLESS
#  22위 그때 그 순간 그대로 (그그그)
#  23위 Bound
#  24위 TOMBOY
#  25위 그라데이션
#  26위 Somebody!
#  27위 Hurt
#  28위 보고싶었어
#  29위 BAD LOVE
#  30위 I Ain't Worried
#  31위 정이라고 하자 (Feat. 10CM)
#  32위 That's Hilarious
#  33위 POP!
#  34위 사랑인가 봐
#  35위 Girls
#  36위 BEAUTIFUL MONSTER
#  37위 통화연결음
#  38위 잠수이별 (Prod. 코드 쿤스트)
#  39위 INVU
#  40위 My Satisfaction
#  41위 나의 X에게
#  42위 Burn
#  43위 FLASH
#  44위 Another Life
#  45위 Guilty Pleasure
#  46위 Sparkling
#  47위 G.O.A.T (Greatest Of All Time)
#  48위 Delight
#  49위 I Can’t Sleep
#  50위 사랑한다고 말해줘
#  51위 Dangerously
#  52위 너의 모든 순간
#  53위 strawberry moon
#  54위 SMILEY (Feat. BIBI)
#  55위 Ain’t Gonna Dance
#  56위 Proud
#  57위 Love story
#  58위 내 기쁨은 너가 벤틀리를 끄는 거야
#  59위 Stay This Way
#  60위 새들처럼
#  61위 다정히 내 이름을 부르면
#  62위 Weekend
#  63위 Next Level
#  64위 That That (prod. & feat. SUGA of BTS)
#  65위 Feel My Rhythm
#  66위 스티커 사진
#  67위 I LOVE U
#  68위 Left and Right (Feat. Jung Kook of BTS)
#  69위 봄여름가을겨울 (Still Life)
#  70위 내가 아니라도
#  71위 SMARTPHONE
#  72위 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)
#  73위 열이올라요 (Heart Burn)
#  74위 STAY
#  75위 LOVE me
#  76위 취중고백
#  77위 Celebrity
#  78위 듣고 싶을까
#  79위 괴짜 (Freak)
#  80위 드라마
#  81위 Off My Face
#  82위 새벽에 걸려온 너의 전화는
#  83위 HOT
#  84위 MY BAG
#  85위 팡파레
#  86위 사랑이야
#  87위 사랑은 늘 도망가
#  88위 난, 너를
#  89위 상상 (Beyond My Dreams)
#  90위 눈을 감으면
#  91위 신호등
#  92위 Light Switch
#  93위 모든 날, 모든 순간 (Every day, Every Moment)
#  94위 늦은 밤 헤어지긴 너무 아쉬워
#  95위 GANADARA (Feat. 아이유)
#  96위 별빛처럼
#  97위 우리, 여기
#  98위 Lovesick Girls
#  99위 아무래도 난
# 100위 마지막처럼

# %%
# 아티스트 크롤링
artists = soup.findAll('p', {'class': 'artist'})
# print(artists)
# print(len(artists))

for i in range(len(artists)):
    # print('{:3d}위 {}'.format(i + 1, artists[i].text.strip())) # 적절 X
    # print('{:3d}위 {}'.format(i + 1, artists[i].text.split('\n')[1])) # 적절 X
    print('{:3d}위 {}'.format(i + 1, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 IVE (아이브)
#   2위 BLACKPINK
#   3위 NewJeans
#   4위 NewJeans
#   5위 키 (KEY)
#   6위 이보람 (씨야)
#   7위 소녀시대 (GIRLS' GENERATION)
#   8위 TWICE (트와이스)
#   9위 TEMPEST(템페스트)
#  10위 NewJeans
#  11위 마마무+
#  12위 TEMPEST(템페스트)
#  13위 IVE (아이브)
#  14위 TEMPEST(템페스트)
#  15위 TEMPEST(템페스트)
#  16위 TEMPEST(템페스트)
#  17위 ITZY (있지)
#  18위 키 (KEY)
#  19위 aespa
#  20위 IVE (아이브)
#  21위 LE SSERAFIM (르세라핌)
#  22위 WSG워너비 (가야G)
#  23위 키 (KEY)
#  24위 (여자)아이들
#  25위 10CM
#  26위 로꼬
#  27위 NewJeans
#  28위 WSG워너비 (4FIRE)
#  29위 키 (KEY)
#  30위 OneRepublic(원리퍼블릭)
#  31위 BIG Naughty (서동현)
#  32위 Charlie Puth(찰리 푸스)
#  33위 나연 (TWICE)
#  34위 멜로망스(MeloMance)
#  35위 aespa
#  36위 STAYC(스테이씨)
#  37위 보라미유
#  38위 우원재
#  39위 태연 (TAEYEON)
#  40위 IVE (아이브)
#  41위 경서
#  42위 키 (KEY)
#  43위 로켓펀치(Rocket Punch)
#  44위 키 (KEY)
#  45위 키 (KEY)
#  46위 청하
#  47위 키 (KEY)
#  48위 키 (KEY)
#  49위 키 (KEY)
#  50위 탑현
#  51위 Charlie Puth(찰리 푸스)
#  52위 성시경
#  53위 아이유(IU)
#  54위 YENA (최예나)
#  55위 키 (KEY)
#  56위 키 (KEY)
#  57위 볼빨간사춘기
#  58위 김승민
#  59위 프로미스나인
#  60위 멜로망스(MeloMance)
#  61위 경서예지
#  62위 태연 (TAEYEON)
#  63위 aespa
#  64위 싸이 (PSY)
#  65위 Red Velvet (레드벨벳)
#  66위 21학번
#  67위 WINNER
#  68위 Charlie Puth(찰리 푸스)
#  69위 BIGBANG (빅뱅)
#  70위 주호
#  71위 YENA (최예나)
#  72위 이석훈
#  73위 선미
#  74위 The Kid LAROI
#  75위 BE'O (비오)
#  76위 김민석 (멜로망스)
#  77위 아이유(IU)
#  78위 MSG워너비(M.O.M)
#  79위 지코
#  80위 아이유(IU)
#  81위 Justin Bieber(저스틴 비버)
#  82위 한동근
#  83위 세븐틴(SEVENTEEN)
#  84위 (여자)아이들
#  85위 다비치
#  86위 케이시
#  87위 임영웅
#  88위 김필(Kim Feel)
#  89위 선우정아(Sunwoojunga)
#  90위 WSG워너비
#  91위 이무진
#  92위 Charlie Puth(찰리 푸스)
#  93위 폴킴(Paul Kim)
#  94위 케이시
#  95위 박재범
#  96위 Xydo(시도)
#  97위 안예은
#  98위 BLACKPINK
#  99위 주시크 (Joosiq)
# 100위 BLACKPINK

# %%
print(dt.now().strftime('%Y-%m-%d %H:%M:%S'))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{:3d}위 {} - {}'.format(i + 1, artist, title))
# Out:
# 2022-08-30 22:06:53
#   1위 IVE (아이브) - After LIKE
#   2위 BLACKPINK - Pink Venom
#   3위 NewJeans - Hype Boy
#   4위 NewJeans - Attention
#   5위 키 (KEY) - 가솔린 (Gasoline)
#   6위 이보람 (씨야) - 한 밤의 꿈처럼
#   7위 소녀시대 (GIRLS' GENERATION) - FOREVER 1
#   8위 TWICE (트와이스) - Talk that Talk
#   9위 TEMPEST(템페스트) - Can’t Stop Shining
#  10위 NewJeans - Cookie
#  11위 마마무+ - Better (Feat. BIG Naughty)
#  12위 TEMPEST(템페스트) - Bad News
#  13위 IVE (아이브) - LOVE DIVE
#  14위 TEMPEST(템페스트) - Young & Wild
#  15위 TEMPEST(템페스트) - START UP
#  16위 TEMPEST(템페스트) - 하루만
#  17위 ITZY (있지) - SNEAKERS
#  18위 키 (KEY) - Villain (Feat. 제노 of NCT)
#  19위 aespa - 도깨비불 (Illusion)
#  20위 IVE (아이브) - ELEVEN
#  21위 LE SSERAFIM (르세라핌) - FEARLESS
#  22위 WSG워너비 (가야G) - 그때 그 순간 그대로 (그그그)
#  23위 키 (KEY) - Bound
#  24위 (여자)아이들 - TOMBOY
#  25위 10CM - 그라데이션
#  26위 로꼬 - Somebody!
#  27위 NewJeans - Hurt
#  28위 WSG워너비 (4FIRE) - 보고싶었어
#  29위 키 (KEY) - BAD LOVE
#  30위 OneRepublic(원리퍼블릭) - I Ain't Worried
#  31위 BIG Naughty (서동현) - 정이라고 하자 (Feat. 10CM)
#  32위 Charlie Puth(찰리 푸스) - That's Hilarious
#  33위 나연 (TWICE) - POP!
#  34위 멜로망스(MeloMance) - 사랑인가 봐
#  35위 aespa - Girls
#  36위 STAYC(스테이씨) - BEAUTIFUL MONSTER
#  37위 보라미유 - 통화연결음
#  38위 우원재 - 잠수이별 (Prod. 코드 쿤스트)
#  39위 태연 (TAEYEON) - INVU
#  40위 IVE (아이브) - My Satisfaction
#  41위 경서 - 나의 X에게
#  42위 키 (KEY) - Burn
#  43위 로켓펀치(Rocket Punch) - FLASH
#  44위 키 (KEY) - Another Life
#  45위 키 (KEY) - Guilty Pleasure
#  46위 청하 - Sparkling
#  47위 키 (KEY) - G.O.A.T (Greatest Of All Time)
#  48위 키 (KEY) - Delight
#  49위 키 (KEY) - I Can’t Sleep
#  50위 탑현 - 사랑한다고 말해줘
#  51위 Charlie Puth(찰리 푸스) - Dangerously
#  52위 성시경 - 너의 모든 순간
#  53위 아이유(IU) - strawberry moon
#  54위 YENA (최예나) - SMILEY (Feat. BIBI)
#  55위 키 (KEY) - Ain’t Gonna Dance
#  56위 키 (KEY) - Proud
#  57위 볼빨간사춘기 - Love story
#  58위 김승민 - 내 기쁨은 너가 벤틀리를 끄는 거야
#  59위 프로미스나인 - Stay This Way
#  60위 멜로망스(MeloMance) - 새들처럼
#  61위 경서예지 - 다정히 내 이름을 부르면
#  62위 태연 (TAEYEON) - Weekend
#  63위 aespa - Next Level
#  64위 싸이 (PSY) - That That (prod. & feat. SUGA of BTS)
#  65위 Red Velvet (레드벨벳) - Feel My Rhythm
#  66위 21학번 - 스티커 사진
#  67위 WINNER - I LOVE U
#  68위 Charlie Puth(찰리 푸스) - Left and Right (Feat. Jung Kook of BTS)
#  69위 BIGBANG (빅뱅) - 봄여름가을겨울 (Still Life)
#  70위 주호 - 내가 아니라도
#  71위 YENA (최예나) - SMARTPHONE
#  72위 이석훈 - 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)
#  73위 선미 - 열이올라요 (Heart Burn)
#  74위 The Kid LAROI - STAY
#  75위 BE'O (비오) - LOVE me
#  76위 김민석 (멜로망스) - 취중고백
#  77위 아이유(IU) - Celebrity
#  78위 MSG워너비(M.O.M) - 듣고 싶을까
#  79위 지코 - 괴짜 (Freak)
#  80위 아이유(IU) - 드라마
#  81위 Justin Bieber(저스틴 비버) - Off My Face
#  82위 한동근 - 새벽에 걸려온 너의 전화는
#  83위 세븐틴(SEVENTEEN) - HOT
#  84위 (여자)아이들 - MY BAG
#  85위 다비치 - 팡파레
#  86위 케이시 - 사랑이야
#  87위 임영웅 - 사랑은 늘 도망가
#  88위 김필(Kim Feel) - 난, 너를
#  89위 선우정아(Sunwoojunga) - 상상 (Beyond My Dreams)
#  90위 WSG워너비 - 눈을 감으면
#  91위 이무진 - 신호등
#  92위 Charlie Puth(찰리 푸스) - Light Switch
#  93위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  94위 케이시 - 늦은 밤 헤어지긴 너무 아쉬워
#  95위 박재범 - GANADARA (Feat. 아이유)
#  96위 Xydo(시도) - 별빛처럼
#  97위 안예은 - 우리, 여기
#  98위 BLACKPINK - Lovesick Girls
#  99위 주시크 (Joosiq) - 아무래도 난
# 100위 BLACKPINK - 마지막처럼

# %%
# 크롤링한 결과를 텍스트 파일에 저장한다.
# file = open('E:/workspace/output/bugsTOP100.txt', 'w')
file = open('./output/bugsTOP100.txt', 'w')
file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    file.write('{:3d}위 {} - {}\n'.format(i + 1, artist, title))
file.close()
print('파일로 저장완료')
# Out:
# 파일로 저장완료

# %%
with open('./output/bugsTOP100.txt', 'w') as file:
    file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
    for i in range(100):
        artist = artists[i].text.strip().split('\n')[0]
        title = titles[i].text.strip().split('\n')[0]
        file.write('{:3d}위 {} - {}\n'.format(i + 1, artist, title))
print('파일로 저장완료')
# Out:
# 파일로 저장완료

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 화면에 출력한다.
try:
    file = open('./output/bugsTOP100.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line.rstrip())
except FileNotFoundError:
    print('디스크에 파일이 없습니다.')
# Out:
# 2022-08-30 22:06:53
#   1위 IVE (아이브) - After LIKE
#   2위 BLACKPINK - Pink Venom
#   3위 NewJeans - Hype Boy
#   4위 NewJeans - Attention
#   5위 키 (KEY) - 가솔린 (Gasoline)
#   6위 이보람 (씨야) - 한 밤의 꿈처럼
#   7위 소녀시대 (GIRLS' GENERATION) - FOREVER 1
#   8위 TWICE (트와이스) - Talk that Talk
#   9위 TEMPEST(템페스트) - Can’t Stop Shining
#  10위 NewJeans - Cookie
#  11위 마마무+ - Better (Feat. BIG Naughty)
#  12위 TEMPEST(템페스트) - Bad News
#  13위 IVE (아이브) - LOVE DIVE
#  14위 TEMPEST(템페스트) - Young & Wild
#  15위 TEMPEST(템페스트) - START UP
#  16위 TEMPEST(템페스트) - 하루만
#  17위 ITZY (있지) - SNEAKERS
#  18위 키 (KEY) - Villain (Feat. 제노 of NCT)
#  19위 aespa - 도깨비불 (Illusion)
#  20위 IVE (아이브) - ELEVEN
#  21위 LE SSERAFIM (르세라핌) - FEARLESS
#  22위 WSG워너비 (가야G) - 그때 그 순간 그대로 (그그그)
#  23위 키 (KEY) - Bound
#  24위 (여자)아이들 - TOMBOY
#  25위 10CM - 그라데이션
#  26위 로꼬 - Somebody!
#  27위 NewJeans - Hurt
#  28위 WSG워너비 (4FIRE) - 보고싶었어
#  29위 키 (KEY) - BAD LOVE
#  30위 OneRepublic(원리퍼블릭) - I Ain't Worried
#  31위 BIG Naughty (서동현) - 정이라고 하자 (Feat. 10CM)
#  32위 Charlie Puth(찰리 푸스) - That's Hilarious
#  33위 나연 (TWICE) - POP!
#  34위 멜로망스(MeloMance) - 사랑인가 봐
#  35위 aespa - Girls
#  36위 STAYC(스테이씨) - BEAUTIFUL MONSTER
#  37위 보라미유 - 통화연결음
#  38위 우원재 - 잠수이별 (Prod. 코드 쿤스트)
#  39위 태연 (TAEYEON) - INVU
#  40위 IVE (아이브) - My Satisfaction
#  41위 경서 - 나의 X에게
#  42위 키 (KEY) - Burn
#  43위 로켓펀치(Rocket Punch) - FLASH
#  44위 키 (KEY) - Another Life
#  45위 키 (KEY) - Guilty Pleasure
#  46위 청하 - Sparkling
#  47위 키 (KEY) - G.O.A.T (Greatest Of All Time)
#  48위 키 (KEY) - Delight
#  49위 키 (KEY) - I Can’t Sleep
#  50위 탑현 - 사랑한다고 말해줘
#  51위 Charlie Puth(찰리 푸스) - Dangerously
#  52위 성시경 - 너의 모든 순간
#  53위 아이유(IU) - strawberry moon
#  54위 YENA (최예나) - SMILEY (Feat. BIBI)
#  55위 키 (KEY) - Ain’t Gonna Dance
#  56위 키 (KEY) - Proud
#  57위 볼빨간사춘기 - Love story
#  58위 김승민 - 내 기쁨은 너가 벤틀리를 끄는 거야
#  59위 프로미스나인 - Stay This Way
#  60위 멜로망스(MeloMance) - 새들처럼
#  61위 경서예지 - 다정히 내 이름을 부르면
#  62위 태연 (TAEYEON) - Weekend
#  63위 aespa - Next Level
#  64위 싸이 (PSY) - That That (prod. & feat. SUGA of BTS)
#  65위 Red Velvet (레드벨벳) - Feel My Rhythm
#  66위 21학번 - 스티커 사진
#  67위 WINNER - I LOVE U
#  68위 Charlie Puth(찰리 푸스) - Left and Right (Feat. Jung Kook of BTS)
#  69위 BIGBANG (빅뱅) - 봄여름가을겨울 (Still Life)
#  70위 주호 - 내가 아니라도
#  71위 YENA (최예나) - SMARTPHONE
#  72위 이석훈 - 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)
#  73위 선미 - 열이올라요 (Heart Burn)
#  74위 The Kid LAROI - STAY
#  75위 BE'O (비오) - LOVE me
#  76위 김민석 (멜로망스) - 취중고백
#  77위 아이유(IU) - Celebrity
#  78위 MSG워너비(M.O.M) - 듣고 싶을까
#  79위 지코 - 괴짜 (Freak)
#  80위 아이유(IU) - 드라마
#  81위 Justin Bieber(저스틴 비버) - Off My Face
#  82위 한동근 - 새벽에 걸려온 너의 전화는
#  83위 세븐틴(SEVENTEEN) - HOT
#  84위 (여자)아이들 - MY BAG
#  85위 다비치 - 팡파레
#  86위 케이시 - 사랑이야
#  87위 임영웅 - 사랑은 늘 도망가
#  88위 김필(Kim Feel) - 난, 너를
#  89위 선우정아(Sunwoojunga) - 상상 (Beyond My Dreams)
#  90위 WSG워너비 - 눈을 감으면
#  91위 이무진 - 신호등
#  92위 Charlie Puth(찰리 푸스) - Light Switch
#  93위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  94위 케이시 - 늦은 밤 헤어지긴 너무 아쉬워
#  95위 박재범 - GANADARA (Feat. 아이유)
#  96위 Xydo(시도) - 별빛처럼
#  97위 안예은 - 우리, 여기
#  98위 BLACKPINK - Lovesick Girls
#  99위 주시크 (Joosiq) - 아무래도 난
# 100위 BLACKPINK - 마지막처럼
